# %%
import pandas as pd

# %%
df=pd.read_csv("D:\Course\Internship\Python Worksheet - Deadline 8 Oct'2020\data.csv")

# %%
df.head()
# Out:
#        Suburb             Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford       68 Studley St    2.0    h        NaN     SS  Jellis
# 1  Abbotsford        85 Turner St    2.0    h  1480000.0      S  Biggin
# 2  Abbotsford     25 Bloomburg St    2.0    h  1035000.0      S  Biggin
# 3  Abbotsford  18/659 Victoria St    3.0    u        NaN     VB  Rounds
# 4  Abbotsford        5 Charles St    3.0    h  1465000.0     SP  Biggin
#
#          Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  03-09-2016       2.5    3067.0  ...       1.0  1.0     126.0           NaN
# 1  03-12-2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 2  04-02-2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 3  04-02-2016       2.5    3067.0  ...       2.0  1.0       0.0           NaN
# 4  04-03-2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
#
# ...

# %%
df.shape
# Out:
# (23678, 21)

# %%
# Ans1 :- 23678 rows & 21 columns

# %%
df.dtypes
# Out:
# Suburb            object
# Address           object
# Rooms              int64
# Type              object
# Price            float64
# Method            object
# SellerG           object
# Date              object
# Distance         float64
# Postcode           int64
# Bedroom2         float64
# Bathroom         float64
# Car              float64
# Landsize         float64
# BuildingArea     float64
# YearBuilt        float64
# CouncilArea       object
# Lattitude        float64
# Longtitude       float64
# Regionname        object
# Propertycount      int64
# dtype: object

# %%
list1=df[df.isnull().all(axis=1)].index.tolist()

# %%
per=len(list1)*(100/df.sum(axis=1).count())
print("Total number of empty rows :",len(list1))
print("The Percentage of Empty Rows against base is :",per)
# Out:
# Total number of empty rows : 131
# The Percentage of Empty Rows against base is : 0.5532561871779711

# %%
df = df.drop(df.index[list1])

# %%
df.shape
# Out:
# (23547, 21)

# %%
null_value_columns=df.columns[df.isnull().any()].tolist()

# %%
column_wise_null_values=df[null_value_columns].isnull().sum(axis = 0)

# %%
column_wise_null_values
# Out:
# Price             5151
# Distance             1
# Postcode             1
# Bedroom2          4481
# Bathroom          4484
# Car               4626
# Landsize          6137
# BuildingArea     13529
# YearBuilt        12007
# CouncilArea       7891
# Lattitude         4304
# Longtitude        4304
# Regionname           1
# Propertycount        1
# dtype: int64

# %%
print("The Percentage of Empty values against columns are :\n\n",column_wise_null_values*(100/df.sum(axis=1).count()))
# Out:
# The Percentage of Empty values against columns are :
#
#  Price            21.875398
# Distance          0.004247
# Postcode          0.004247
# Bedroom2         19.030025
# Bathroom         19.042766
# Car              19.645815
# Landsize         26.062768
# BuildingArea     57.455302
# YearBuilt        50.991634
# CouncilArea      33.511700
# Lattitude        18.278337
# Longtitude       18.278337
# Regionname        0.004247
# Propertycount     0.004247
# dtype: float64

# %%
null_value_rows=df[df.isnull().any(axis=1)].index.tolist()

# %%
null_value_rows
# Out:
# [0,
#  1,
#  3,
#  5,
#  7,
#  8,
#  9,
#  10,
#  12,
#  13,
#  15,
#  16,
#  17,
#  19,
#  20,
#  21,
#  22,
#  23,
#  26,
#  27,
#  28,
#  29,
#  32,
#  34,
#  35,
#  37,
#  40,
#  41,
#  42,
#  46,
#  47,
#  48,
#  49,
#  51,
#  53,
#  54,
#  55,
#  56,
#  61,
#  63,
#  65,
#  66,
#  70,
#  75,
#  76,
#  77,
#  78,
#  79,
#  80,
#  81,
#  85,
#  88,
#  90,
#  92,
#  93,
#  94,
#  95,
#  96,
#  97,
#  98,
#  100,
#  102,
#  103,
#  106,
#  108,
#  111,
#  112,
#  116,
#  117,
#  118,
#  119,
#  120,
#  121,
#  122,
#  123,
#  124,
#  125,
#  126,
#  127,
#  128,
#  129,
#  131,
#  132,
#  133,
#  135,
#  138,
#  140,
#  141,
#  142,
#  144,
#  145,
#  147,
#  149,
#  151,
#  152,
#  154,
#  155,
#  157,
#  158,
#  159,
#  161,
#  164,
#  165,
#  166,
#  168,
#  170,
#  171,
#  172,
#  174,
#  175,
#  176,
#  180,
#  181,
#  182,
#  183,
#  185,
#  186,
#  188,
#  189,
#  190,
#  191,
#  193,
#  195,
#  197,
#  198,
#  199,
#  200,
#  201,
#  204,
#  207,
#  208,
#  209,
#  210,
# ...

# %%
row_wise_null_values=df.loc[null_value_rows].isnull().sum(axis=1)

# %%
row_wise_null_values
# Out:
# 0        3
# 1        2
# 3        3
# 5        2
# 7        1
#         ..
# 23673    2
# 23674    8
# 23675    4
# 23676    1
# 23677    2
# Length: 17351, dtype: int64

# %%
High_missing_value_columns=column_wise_null_values[column_wise_null_values*(100/df.sum(axis=1).count())>=30]

# %%
High_missing_value_columns
# Out:
# BuildingArea    13529
# YearBuilt       12007
# CouncilArea      7891
# dtype: int64

# %%
#del df[['BuildingArea','YearBuilt','CouncilArea']]
df.drop(['BuildingArea','YearBuilt','CouncilArea'], axis=1, inplace=True)

# %%
df.shape
# Out:
# (23547, 18)

# %%
High_missing_value_rows=row_wise_null_values[row_wise_null_values>5]

# %%
High_missing_value_rows
# Out:
# 15       9
# 16       9
# 19       9
# 21       9
# 22       9
#         ..
# 23633    9
# 23636    6
# 23639    9
# 23662    9
# 23674    8
# Length: 4492, dtype: int64

# %%
print("Total Count which have row wise more then 5 missing values :",len(High_missing_value_rows))
print("The Percentage against total base :",len(High_missing_value_rows)*(100/df.sum(axis=1).count()))
# Out:
# Total Count which have row wise more then 5 missing values : 4492
# The Percentage against total base : 19.07674013674778

# %%
# its not more then 20%, so i have remove the same.

# %%
df = df.drop(row_wise_null_values[row_wise_null_values > 5].index)

# %%
df.shape
# Out:
# (19055, 18)

# %%
df.describe()
# Out:
#               Rooms         Price      Distance      Postcode      Bedroom2  \
# count  19055.000000  1.492600e+04  19055.000000  19055.000000  19055.000000
# mean       2.975020  1.067117e+06     10.222556   3109.772763      2.951929
# std        0.972329  6.382375e+05      6.055921     93.808492      0.996002
# min        1.000000  8.500000e+04      0.000000   3000.000000      0.000000
# 25%        2.000000  6.410000e+05      6.100000   3048.000000      2.000000
# 50%        3.000000  9.000000e+05      9.200000   3101.000000      3.000000
# 75%        4.000000  1.320000e+06     13.000000   3150.000000      4.000000
# max       10.000000  9.000000e+06     48.100000   3977.000000     30.000000
#
#            Bathroom           Car       Landsize     Lattitude    Longtitude  \
# count  19054.000000  18921.000000   17408.000000  19029.000000  19029.000000
# mean       1.570956      1.626235     551.822151    -37.812187    145.000471
# ...

# %%
null_value_columns=df.columns[df.isnull().any()].tolist()

# %%
print("The Percentage of Empty values against columns are :\n\n",df[null_value_columns].isnull().sum(axis = 0)*(100/df.sum(axis=1).count()))
# Out:
# The Percentage of Empty values against columns are :
#
#  Price         21.668853
# Bathroom       0.005248
# Car            0.703227
# Landsize       8.643401
# Lattitude      0.136447
# Longtitude     0.136447
# dtype: float64

# %%
df['Price'].fillna(df['Price'].mean(),inplace=True)

# %% [raw]
# Since Price is the target column:
#     1. It cannot be have the nun values.
#     2. As per the data minimum value of the price column is 300000 & highest value is 9000000.
#     3. So, mode cannot be applied due to uncommon values & median cannot be applied due to large difference between the lower & highest values.
#     4. Therefore, i have applied the mean method to fill the blank values in price column.

# %%
print("The Percentage of Empty values against columns are :\n\n",df[null_value_columns].isnull().sum(axis = 0)*(100/df.sum(axis=1).count()))
# Out:
# The Percentage of Empty values against columns are :
#
#  Price         0.000000
# Bathroom      0.005248
# Car           0.703227
# Landsize      8.643401
# Lattitude     0.136447
# Longtitude    0.136447
# dtype: float64

# %% [raw]
# 1. In bathroom column, the most common value is 1, so i replace it with the same.
# 2. In Car column, the most common value is 2, so i replace it with the same.
# 3. In Lattitude column, difference between the lower & highest value is small, so i replace it with the mean value.
# 4. In Longtitude column, difference between the lower & highest value is small, so i replace it with the mean value.

# %%
df['Bathroom'].fillna(df['Bathroom'].median(),inplace=True)
df['Car'].fillna(df['Car'].median(),inplace=True)
df['Landsize'].fillna(df['Landsize'].mean(),inplace=True)
df['Lattitude'].fillna(df['Lattitude'].median(),inplace=True)
df['Longtitude'].fillna(df['Longtitude'].median(),inplace=True)

# %%
print("The Percentage of Empty values against columns are :\n\n",df[null_value_columns].isnull().sum(axis = 0)*(100/df.sum(axis=1).count()))
# Out:
# The Percentage of Empty values against columns are :
#
#  Price         0.0
# Bathroom      0.0
# Car           0.0
# Landsize      0.0
# Lattitude     0.0
# Longtitude    0.0
# dtype: float64

# %%
1. As per data cleaning 3 columns has been removed from the dataset due to highest count of missing values in it.
2. About 14% columns wise data has been removed.
3. Aproxx. 19% data has been removed due to completley blank rows & missing values.
4. According to me, the removed data is justified because this can be decrease the quality of model & definatley effects the accuracy for the same.
